# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Задание
#
# ![image.png](attachment:d1e6cf63-da92-45d5-8385-355ee4880475.png)

# %% [markdown]
# ## Теория
#
# ![image.png](attachment:31e8f824-5bef-43e4-8f83-39a8ef28aae7.png)

# %% [markdown]
# ## Расчёт коэффициентов

# %% [markdown]
# ![image.png](attachment:045eaea4-e78b-4366-b670-acd51b3450e9.png)

# %% [markdown]
# ![image.png](attachment:f7e9c674-38e5-40c0-a3e0-afae4cb07ffe.png)

# %%
h = 0.005
N = int(1/h)

x = np.array(np.linspace(0, 1, N))

p = np.array([0 for xn in x])
q = np.array([-(10 + np.sin(2*np.pi*xn)) for xn in x])
f = np.array([np.cos(2*np.pi*xn) for xn in x])

a = 1 - 1/2 * p * h
b = 2 - q * h**2
c = 1 + 1/2 * p * h
phi = f * h**2

alpha = np.zeros(N)
beta  = np.zeros(N)
gamma = np.zeros(N)
alpha[1] = c[0]/b[0]
beta[1] = -phi[0]/b[0]
gamma[1] = a[0]/b[0]

for k in range(1, N - 1):
    alpha[k+1] = c[k]/(b[k] - alpha[k]*a[k])
    beta[k+1] = (a[k]*beta[k] - phi[k]) / (b[k] - alpha[k]/a[k])
    gamma[k+1] = a[k]*gamma[k] / (b[k] - alpha[k]*a[k])

# %% [markdown]
# ![image.png](attachment:def6b4e6-046d-46a1-b4e4-2f1ede67bc66.png)

# %%
mu = np.zeros(N)
nu = np.zeros(N)

mu[N-1] = -c[N-1] / (a[N-1]*(alpha[N-1] + gamma[N-1]) - b[N-1])
nu[N-1] = (phi[N-1] - a[N-1]*beta[N-1]) / (a[N-1]*(alpha[N-1] + gamma[N-1]) - b[N-1])

for n in range(N - 1, 0, -1):
    mu[n-1] = alpha[n]*mu[n] + gamma[n]*mu[N-1]
    nu[n-1] = beta[n] + alpha[n]*nu[n] + gamma[n]*nu[N-1]

# %% [markdown]
# ## Решение

# %%
y = np.zeros(N)

y[0] = nu[0] / (1 - mu[0])
y[N-1] = mu[N-1]*y[0] + nu[N-1]

for n in range(N - 1, 0, -1):
    y[n-1] = alpha[n]*y[n] + beta[n] + gamma[n]*y[N-1]

y = np.tile(y, 5)
n = np.linspace(0, 5 * N - 1, 5 * N)

# %% [markdown]
# ## Визуализация

# %%
plt.plot(n, y)

plt.title('y(x)')
plt.xlabel('x')

plt.ylabel('y')
plt.show()
